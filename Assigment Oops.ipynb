# %% [markdown]
# Assigment of Oops:-

# %% [markdown]
# # Answer 1:-
#
# a) **Encapsulation**: Creating attributes and fnctions that operate on data within single object.
# **Examples Below**:-

# %%
class BankAccount:
    def __init__(self, owner, balance=50):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
      if amount > 50:
        self.__balance += amount

    def withdraw(self, amount):
      if 0 < amount <= self.__balance:
        self.__balance -= amount

    def get_balance(self):
      return self.__balance

account = BankAccount("Diksha")
account.deposit(1100)
print(account.get_balance())
# Out:
# 1150

# %% [markdown]
# b) **Abstraction**: Doing Complex reality by modle classes based on essential properties and behaviors.
#
# **Example Below:-**

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

    def area(self):
      return 3.14 * self.radius * self.radius

# %% [markdown]
# c) **Inheritance**: Method where new class inhertis properties and behaviours from an existing class.
#
#
# **Example Below:**

# %%
class Animal:
  def speak(self):
    return "Animal speaks"

class Dog(Animal):
  def speak(self):
    return "Bark"

class Cat(Animal):
  def speak(self):
    return "Meow"

dog = Dog()
cat = Cat()
print(dog.speak())
print(cat.speak())
# Out:
# Bark
# Meow

# %% [markdown]
# d) **Polymorphism**:- Ability to present the interface for different underlying data types.It allows methods to varities thing based on the object
#
# **Example Below:**

# %%
class Bird:
  def speak(self):
    return"chirp"

class Fish:
  def speak(self):
    return "Blub"

def animal_sound(animal):
  print(animal.speak())

bird = Bird()
fish = Fish()
animal_sound(bird)
animal_sound(fish)
# Out:
# chirp
# Blub

# %% [markdown]
# e) **Composition**:- design principe where class is composed one or more objects from other class, allows for great resue.
#
# **Example Below:**

# %%
class Engine:
  def start(self):
    return "Engine starting"

class Car:
  def __init__(self):
    self.engine = Engine()

  def start(self):
    return self.engine.start() + " and Car is ready"

car = Car()
print(car.start())
# Out:
# Engine starting and Car is ready

# %%
Ans 2:

# %% [markdown]
# **Ans 2:-**

# %%
class Car:
  def __init__(self, make, model, year):
    self.make = make
    self.model = model
    self.year = year

    def display_info(self):
      print(f"Car Information: {self.year} {self.make} {self.model}")

# %% [markdown]
# **Ans 3:-**Difference Between class and instant method.
#
# a) **Instance Method** :- This is most common method.
# It is associatedwith instant of class, it can access and modify attributes.
#
# Example Below:-

# %%
class Dog:
  def __init__(self, name):
    self.name = name

    def bark(self):
      print(f"{self.name} is speaking")
      dog = Dog("Buddy")
      dog.Bark

# %% [markdown]
# b) **Class Method**:- It is associated with the class itself. In this we cnt modify specific data,but class can be modified. To define this we need to use
# @clsmethod.
#
# Example Below:-

# %%
class Dog:
  species = "Canis familiaris"

  @classmethod
  def species_type(cls):
    return f"All dogs are {cls.species}."
    print(Dog.species_type())

# %% [markdown]
# **Ans 4:-**Python doesn'tsupport traditional method of overloading .
# We can achiever methods by different ways like
# a): Deafult aruguments
# b): *args
# c): difference between different arugment combinations.
#
# **Example Below:**

# %%
class Math:
  def add(self, *args):
    return sum(args)
    Math = Math()
    print(Math.add(1, 2, 3, 4))

# %%
print(Math.add(2, 3, 4, 5))
# Out:
# 12

# %% [markdown]
# **Ans 5**:- Three types of access modifier in Python are:
#
# a) Public: No prefix from anywhere it can access
#
# b) Protected: Denoted by single underscore**(_)**
#
# c) Private: Denoted by double underscore**(__)**
#
# **Example Below of each:-**

# %%
#Public:-

# %%
class MyClass:
  def __init__(self):
    self.public_var = "I am Diksha"

  def public_method(self):
    return "This is public method"

obj = MyClass()
print(obj.public_var)
print(obj.public_method())
# Out:
# I am Diksha
# This is public method

# %%
#Protected:-

# %%
class MyClass:
  def __init__(self):
    self._protected_var = "I am Diksha"

    def _protected_var(self):
      return "This is protectted methof"

obj = MyClass()
print(obj._protected_var)
# Out:
# I am Diksha

# %%
#Private

# %%
class MyClass:
  def __init__(self):
    self.__private_var = "I am Diksha"

    def __private_var(self):
      return "This is private method"
      obj = MyClass()
      print(obj._MyClass__private_var)

# %% [markdown]
# **Ans 6:** Five Types of inheritance in Python

# %% [markdown]
# a) **Single Inheritance**:- Children class inherits from single parent class.
#
# b) **Hybrid Inheritance**:- Combination of 2 or more types of inheritance. Such as multiple and hierarchical.
#
# c) **Multilevel Inheritance**:- Children class inherit from parent class and next
#   class inherits from child class, it forms chain.
#
# d) **Hierarchical**:- Multiple children inherit from same parentclass.
#
# e) **Multiple Inheritance**:- Children class inherit from more then one parent class
#
# **Example for Multiple Inheritance below:-**

# %%
class Animal:
  def speak(self):
    print("Animal speaks")

class Bird:
  def fly(self):
    print("Bird flies")

class Bat(Animal, Bird):
  def sound(self):
    print("Bat makes a sound")

b = Bat()
b.speak()
b.fly()
b.sound()
# Out:
# Animal speaks
# Bird flies
# Bat makes a sound

# %% [markdown]
# **Ans 7:-**
# Method for Resolution Order MRO in Python:- It is order in which python looks for methods and attributes in hierachy of classes during inheritance.
#
#
# Retrieve MRO Programmatically has 2 ways:
#
# a) using the **__mro__**
#
# b) useint the **mro()**

# %%
#__mro__

class A:
  pass

class B:
  pass

class C(B):
  pass

print(C.__mro__)
# Out:
# (<class '__main__.C'>, <class '__main__.B'>, <class 'object'>)

# %%
#mro()

class A:
  pass

class B(A):
  pass

class C(B):
  pass

print(C.mro())
# Out:
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
#Mutiple Inheritance

class X:
  def who_am_i(self):
    print("I am X")

class Y(X):
  def who_am_i(self):
    print("I am Y")

class Z(X):
  def who_am_i(self):
    print("I am Z")

class A(Y, Z):
  pass

a = A()
a.who_am_i()
print(A.mro())
# Out:
# I am Y
# [<class '__main__.A'>, <class '__main__.Y'>, <class '__main__.Z'>, <class '__main__.X'>, <class 'object'>]

# %% [markdown]
# **Ans 8:-** Abstract Base Class

# %%
from abc import ABC, abstractmethod
import math

#abstarct base class
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

#subclass Circle
class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def area(self):
    return math.pi * self.radius ** 4

# Subclass Rectangle
class Rectangle(Shape):
  def __init__(self, width, height):
    self.width = width
    self.heigh = height

  def area(self):
    return self.width * self.height

# create instances and area method
circle = Circle(5)
print(f"Circle Area:{circle.area():.2}")
# Out:
# Circle Area:2e+03

# %% [markdown]
# **Ans 9**:-Create Function that can workwith different shape.

# %%
from abc import ABC, abstractmethod
import math

#abstarct base class
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

#subclass Circle
class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def area(self):
    return math.pi * self.radius ** 4

# Subclass Rectangle
class Rectangle(Shape):
  def __init__(self, width, height):
    self.width = width
    self.heigh = height

  def area(self):
    return self.width * self.height

# Function Demonstracting Polymorphism
def print_area(shape):
  print(f"The area of the {shape.__class__.__name__} is:{shape.area():.2f}")

# creating instance of circle and rectangle
circle = Circle(3)
print_area(circle)
# Out:
# The area of the Circle is:254.47

# %% [markdown]
# **Ans 10:-**

# %%
class Bank:

  def __init__(self, balance):
    self._balance = balance

    def deposit(self, amount):
      if amount >0:
        self.balance += amount

        def withdraw(self, amount):
          if 0 < amount <= self.balance:
            self.balance -= amount

            def get_balance(self):
              return self.balance

# %%
def get_balance(self):
  return self.balance

# %% [markdown]
# **Ans 11:-**
#
# a) **__str__**: It allows to customize how to object represt as a string
#
# b) **__add__**: It allows to define happens when we use the + opreator with instance of class.

# %%
class MyClass:
  def __init__(self, value):
    self.value = value

    # Overriding the __str__method to cstomize object print
    def __str__(self):
      return f"MyClass instance with value:{self.vale}"

    # Overriding the __add__ method to define how addition works
    def __add__(self, other):
      if isinstance(other, MyClass):
        return MyClass(self.value + other.value)

# %% [markdown]
# Ans 12:- Decorator that measures and print the excution time.

# %%
import time

# Decorator to measure execution time
def measure_time(func):
  def wrapper(*args, **kwargs):
    start_time = time.time()
    result = fnc(*args, **kwargs)
    end_time = time.time()
    execution_time = end_time - start_time

# %% [markdown]
# **Ans 13**:- Diamond problem >> it occurs when class inherit from 2 or more class will lead to ambiguity in exceution of methods.

# %%
class A:
  def greet(self):
    print("Hello from A")

    class B(A):
      def greet(self):
        print("Hello from B")

        class C(A):
          def greet(self):
            print("Hello from C")

            class D(B, C):
              pass

              # Create instances and call greet method
              a = A()
              a.greet()

              b = B()
              b.greet()

              c = C()
              c.greet()

              d = D()
              d.greet()

# %% [markdown]
# **Ans 14:-**

# %%
class MyClass:
  instance_cont = 0

  def __init__(self):
    MyClass.instance_count += 1

    @classmethod
    def get_instance_count(cls):
      return f"Number of instancee created: {cls.instance_count}"

# %% [markdown]
# **Ans 15:-**

# %%
class YearChecker:
  @staticmethod
  def is_leap_year(year):
    if (year % 4 == 0 and year % 100 !=0) or year % 400 == 0:
      return True

    return False

# %%
print(YearChecker.is_leap_year(2024))
# Out:
# True

# %%
print(YearChecker.is_leap_year(2022))
# Out:
# False
